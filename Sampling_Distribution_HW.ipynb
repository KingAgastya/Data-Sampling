# %% [markdown]
# <a href="https://colab.research.google.com/github/KingAgastya/Data-Sampling/blob/main/Sampling_Distribution_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
fileData = files.upload()
# Out:
#      <input type="file" id="files-e6b49cf2-b422-4b56-96ba-6d79a5e1efe7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e6b49cf2-b422-4b56-96ba-6d79a5e1efe7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data.csv to data.csv

# %%
import csv
import pandas as pd
import plotly.figure_factory as ff

f = pd.read_csv('data.csv')

fileData = f['reading_time'].tolist()

fig = ff.create_distplot([fileData], ['Reading Times'], show_hist = False)
fig.show()

#It does not follow normal distribution

# %%
import statistics as st
import random

population_mean = st.mean(fileData)

means = []

def random_means(n):
  numbers = []
  for i in range(0, n):
    random_index = random.randint(0, (len(fileData) - 1))
    numbers.append(fileData[random_index])
  
  mean = st.mean(numbers)
  return mean

def setup(num):
  for j in range(0, num):
    meanData = random_means(30)
    means.append(meanData)

  print(means)

def plot_graph():
  fig = ff.create_distplot([means], ['Reading Times'], show_hist = False)
  fig.show()

setup(100)
plot_graph()

sampling_mean = st.mean(means)

print(f'Population Mean = {population_mean}')
print(f'Sampling Mean = {sampling_mean}')
# Out:
# [6.3, 6.5, 5.466666666666667, 5.8, 6.566666666666666, 5.766666666666667, 5.933333333333334, 5.533333333333333, 6.833333333333333, 6.433333333333334, 6.4, 6.566666666666666, 5.433333333333334, 6.7, 5.2, 6.033333333333333, 5.7, 5.333333333333333, 6.066666666666666, 5.7, 5.8, 6.566666666666666, 6.566666666666666, 6.2, 6.033333333333333, 6.366666666666666, 5.133333333333334, 6.033333333333333, 5.8, 5.866666666666666, 6.533333333333333, 6.033333333333333, 6, 8.066666666666666, 6, 7.566666666666666, 5.433333333333334, 5.933333333333334, 6.266666666666667, 5.866666666666666, 5.766666666666667, 6.1, 7.666666666666667, 6.133333333333334, 5.433333333333334, 5.266666666666667, 5.966666666666667, 5.533333333333333, 5.6, 5.433333333333334, 6.6, 5.5, 7.666666666666667, 6.1, 5.9, 6.3, 6.366666666666666, 6.133333333333334, 5.7, 7.366666666666666, 6.433333333333334, 6.4, 6, 5.733333333333333, 5.466666666666667, 5.766666666666667, 6.4, 5.833333333333333, 6.5, 6.033333333333333, 6.333333333333333, 5.7, 5.9, 6.066666666666666, 6.066666666666666, 5.3, 6.8, 6.066666666666666, 5.5, 6.033333333333333, 6.266666666666667, 6.966666666666667, 5.7, 6.9, 6.366666666666666, 6.533333333333333, 5.7, 6.566666666666666, 6.533333333333333, 6.233333333333333, 6.166666666666667, 6.9, 6.066666666666666, 6.966666666666667, 6, 7.166666666666667, 5.833333333333333, 6.066666666666666, 6.833333333333333, 6.166666666666667]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b03c35c2-8017-4158-92de-873f70108422" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b03c35c2-8017-4158-92de-873f70108422")) {                    Plotly.newPlot(                        "b03c35c2-8017-4158-92de-873f70108422",                        [{"legendgroup":"Reading Times","marker":{"color":"rgb(31, 119, 180)"},"mode":"lines","name":"